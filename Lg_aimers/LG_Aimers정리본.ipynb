# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip -qq "/content/drive/MyDrive/LG/open.zip"
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset Info.
#
# ### train.csv [파일]
# - ID : 실제 판매되고 있는 고유 ID
# - 제품 : 제품 코드
# - 대분류 : 제품의 대분류 코드
# - 중분류 : 제품의 중분류 코드
# - 소분류 : 제품의 소분류 코드
# - 브랜드 : 제품의 브랜드 코드
# - 2022-01-01 ~ 2023-04-04 : 실제 일별 판매량
# - 단, 제품이 동일하여도 판매되고 있는 고유 ID 별로 기재한 분류 정보가 상이할 수 있음
# - 즉 고유 ID가 다르다면, 제품이 같더라도 다른 판매 채널

# %%
train= pd.read_csv('./train.csv')

# %% [markdown]
# ### 제품, (대,중,소)분류, 브랜드 중요 값 추출

# %%
train_pro = train.iloc[:,1:6]
train_pro.head()
# Out:
#                  제품             대분류             중분류             소분류  \
# 0  B002-00001-00001  B002-C001-0002  B002-C002-0007  B002-C003-0038
# 1  B002-00002-00001  B002-C001-0003  B002-C002-0008  B002-C003-0044
# 2  B002-00002-00002  B002-C001-0003  B002-C002-0008  B002-C003-0044
# 3  B002-00002-00003  B002-C001-0003  B002-C002-0008  B002-C003-0044
# 4  B002-00003-00001  B002-C001-0001  B002-C002-0001  B002-C003-0003
#
#           브랜드
# 0  B002-00001
# 1  B002-00002
# 2  B002-00002
# 3  B002-00002
# 4  B002-00003

# %%
train_pro["제품"].value_counts() # 이름 같은 것이 있다.
# Out:
# B002-00070-00009    2
# B002-01083-00002    2
# B002-03481-00001    2
# B002-03796-00008    2
# B002-01523-00045    2
#                    ..
# B002-01277-00015    1
# B002-01277-00016    1
# B002-01277-00017    1
# B002-01277-00018    1
# B002-03799-00010    1
# Name: 제품, Length: 15840, dtype: int64

# %%
train_pro["제품1"] = train_pro["제품"].map(lambda x : x.split("-")[0])
train_pro["제품2"] = train_pro["제품"].map(lambda x : x.split("-")[1])
train_pro["제품3"] = train_pro["제품"].map(lambda x : x.split("-")[2])

# %%
print(train_pro["제품1"].value_counts())
print(train_pro["제품2"].value_counts())
# Out:
# B002    15890
# Name: 제품1, dtype: int64
# 00894    153
# 00266    153
# 00680    148
# 00434    136
# 02052    113
#         ...
# 00307      1
# 01370      1
# 02474      1
# 00309      1
# 00001      1
# Name: 제품2, Length: 3168, dtype: int64

# %%
print(train_pro["제품3"].value_counts())
# Out:
# 00001    3053
# 00002    1633
# 00003    1113
# 00004     871
# 00005     704
#          ...
# 00170       1
# 00171       1
# 00172       1
# 00175       1
# 00163       1
# Name: 제품3, Length: 186, dtype: int64

# %%
train_pro["대분류1"] = train_pro["대분류"].map(lambda x : x.split("-")[0])
train_pro["대분류2"] = train_pro["대분류"].map(lambda x : x.split("-")[1])
train_pro["대분류3"] = train_pro["대분류"].map(lambda x : x.split("-")[2])

# %%
print(train_pro['대분류1'].value_counts())
print(train_pro['대분류2'].value_counts())
print(train_pro['대분류3'].value_counts())
# Out:
# B002    15890
# Name: 대분류1, dtype: int64
# C001    15890
# Name: 대분류2, dtype: int64
# 0002    10954
# 0001     3768
# 0005      613
# 0003      444
# 0004      111
# Name: 대분류3, dtype: int64

# %%
train_pro["중분류1"] = train_pro["중분류"].map(lambda x : x.split("-")[0])
train_pro["중분류2"] = train_pro["중분류"].map(lambda x : x.split("-")[1])
train_pro["중분류3"] = train_pro["중분류"].map(lambda x : x.split("-")[2])

# %%
print(train_pro['중분류1'].value_counts())
print(train_pro['중분류2'].value_counts())
print(train_pro['중분류3'].value_counts())
# Out:
# B002    15890
# Name: 중분류1, dtype: int64
# C002    15890
# Name: 중분류2, dtype: int64
# 0001    3608
# 0007    2501
# 0005    2275
# 0006    1675
# 0003    1516
# 0004    1168
# 0009    1144
# 0002     946
# 0011     613
# 0008     410
# 0010      34
# Name: 중분류3, dtype: int64

# %%
train_pro["소분류1"] = train_pro["소분류"].map(lambda x : x.split("-")[0])
train_pro["소분류2"] = train_pro["소분류"].map(lambda x : x.split("-")[1])
train_pro["소분류3"] = train_pro["소분류"].map(lambda x : x.split("-")[2])

# %%
print(train_pro['소분류1'].value_counts())
print(train_pro['소분류2'].value_counts())
print(train_pro['소분류3'].value_counts())
# Out:
# B002    15890
# Name: 소분류1, dtype: int64
# C003    15890
# Name: 소분류2, dtype: int64
# 0003    1426
# 0034    1020
# 0001     751
# 0025     690
# 0002     663
# 0035     641
# 0015     466
# 0040     451
# 0039     432
# 0038     431
# 0004     426
# 0027     408
# 0052     392
# 0041     366
# 0023     365
# 0036     362
# 0022     356
# 0005     342
# 0016     342
# 0045     294
# 0024     289
# 0032     265
# 0007     262
# 0014     236
# 0044     234
# 0046     223
# 0017     222
# 0053     221
# 0029     198
# 0021     195
# 0049     194
# 0037     184
# 0009     183
# 0033     180
# 0006     175
# 0028     174
# 0048     162
# 0051     160
# 0030     153
# 0026     150
# 0019     140
# 0043     117
# 0010     113
# 0020     112
# 0008     112
# 0047     111
# 0013     104
# 0011     101
# 0012      75
# 0018      71
# 0042      59
# 0031      57
# 0050      34
# Name: 소분류3, dtype: int64

# %%
train_pro['브랜드1'] = train_pro['브랜드'].map(lambda x : x.split('-')[0])
train_pro['브랜드2'] = train_pro['브랜드'].map(lambda x : x.split('-')[1])

# %%
print(train_pro['브랜드1'].value_counts())
print(train_pro['브랜드2'].value_counts())
# Out:
# B002    15890
# Name: 브랜드1, dtype: int64
# 00894    153
# 00266    153
# 00680    148
# 00434    136
# 02052    113
#         ...
# 01641      1
# 01638      1
# 01637      1
# 01636      1
# 01876      1
# Name: 브랜드2, Length: 3170, dtype: int64

# %%
train_pro_drop=train_pro.drop(columns = ["제품","제품1","대분류", "대분류1","대분류2","중분류", "중분류1", "중분류2", "소분류", "소분류1", "소분류2", '브랜드', "브랜드1"])

# %%
train_pro_drop
# Out:
#          제품2    제품3  대분류3  중분류3  소분류3   브랜드2
# 0      00001  00001  0002  0007  0038  00001
# 1      00002  00001  0003  0008  0044  00002
# 2      00002  00002  0003  0008  0044  00002
# 3      00002  00003  0003  0008  0044  00002
# 4      00003  00001  0001  0001  0003  00003
# ...      ...    ...   ...   ...   ...    ...
# 15885  03799  00002  0003  0008  0042  03799
# 15886  03799  00003  0003  0008  0044  03799
# 15887  03799  00004  0003  0008  0044  03799
# 15888  03799  00005  0003  0008  0044  03799
# 15889  03799  00010  0002  0004  0020  03799
#
# [15890 rows x 6 columns]

# %% [markdown]
# ### 브랜드2 와 제품2의 관련에 대해서 한번 찾아보자!!

# %%
train_pro_drop[train_pro_drop['제품2'] != train_pro_drop['브랜드2']]
# Out:
#          제품2    제품3  대분류3  중분류3  소분류3   브랜드2
# 543    00134  00004  0001  0001  0004  01236
# 2161   00519  00002  0002  0005  0025  03284
# 2440   00616  00003  0002  0007  0039  02656
# 4865   01158  00001  0001  0001  0001  02376
# 5993   01523  00008  0002  0004  0022  02908
# 5998   01523  00012  0002  0004  0022  02908
# 6000   01523  00013  0002  0004  0023  02908
# 6025   01523  00045  0002  0004  0022  02908
# 8089   01950  00022  0002  0003  0015  02656
# 8370   02005  00002  0001  0009  0051  03122
# 9514   02232  00002  0001  0001  0002  00669
# 9516   02232  00003  0001  0001  0002  00669
# 9518   02232  00004  0001  0001  0002  00669
# 9520   02232  00005  0001  0001  0002  00669
# 9522   02232  00006  0001  0001  0003  00669
# 9524   02232  00007  0001  0001  0003  00669
# 9527   02232  00009  0001  0001  0003  00669
# 9541   02232  00027  0001  0001  0003  00669
# 13232  03129  00001  0002  0005  0025  01322

# %%
train_pro_drop[train_pro_drop['제품2'] != train_pro_drop['브랜드2']]['브랜드2'].value_counts()
# Out:
# 00669    8
# 02908    4
# 02656    2
# 01236    1
# 03284    1
# 02376    1
# 03122    1
# 01322    1
# Name: 브랜드2, dtype: int64

# %% [markdown]
# 여기부터 시각화

# %%
train= pd.read_csv('./train.csv')
sales = pd.read_csv('sales.csv')
product = pd.read_csv('./product_info.csv')
key = pd.read_csv('./brand_keyword_cnt.csv')
submission = pd.read_csv('./sample_submission.csv')

# %%
# 1~12

Year = [
'B002-00113-00001',
'B002-02723-00004',
'B002-02920-00005',
'B002-01069-00002',
'B002-00809-00002',
'B002-02920-00016',
'B002-00894-00087',
'B002-02920-00008',
'B002-02783-00004',
'B002-00894-00088',
'B002-03436-00017',
'B002-02920-00009',
'B002-01069-00003',
'B002-00894-00024',
'B002-02063-00013']

# 1~6

Year= [
'B002-02920-00005',
'B002-00113-00001',
'B002-01069-00002',
'B002-02723-00004',
'B002-02920-00016',
'B002-02920-00008',
'B002-02920-00009',
'B002-02063-00013',
'B002-02920-00020',
'B002-02783-00004',
'B002-01069-00003',
'B002-00894-00087',
'B002-00894-00024',
'B002-00894-00088',
'B002-00809-00002']

# 7~12
Year=[
'B002-02723-00004',
'B002-00113-00001',
'B002-02920-00005',
'B002-00809-00002',
'B002-03436-00017',
'B002-01069-00002',
'B002-02920-00004',
'B002-02783-00004',
'B002-00894-00088',
'B002-00894-00087',
'B002-03436-00011',
'B002-02525-00012',
'B002-02920-00008',
'B002-02920-00016',
'B002-01069-00003']



# 1분기
Year =[
'B002-02920-00005',
'B002-00113-00001',
'B002-01069-00002',
'B002-02920-00009',
'B002-02723-00004',
'B002-02920-00020',
'B002-02920-00008',
'B002-00894-00024',
'B002-02063-00013',
'B002-02783-00004',
'B002-01069-00003',
'B002-00894-00126',
'B002-00784-00001',
'B002-00894-00087',
'B002-02920-00016']

# 2분기
Year =[
'B002-00113-00001',
'B002-02920-00005',
'B002-02920-00016',
'B002-01069-00002',
'B002-02723-00004',
'B002-02920-00008',
'B002-02063-00013',
'B002-02525-00012',
'B002-02783-00004',
'B002-00894-00087',
'B002-01069-00003',
'B002-01755-00003',
'B002-00894-00088',
'B002-00809-00002',
'B002-02920-00009']

# 3분기

Year =[
'B002-00113-00001'
'B002-02723-00004'
'B002-01069-00002'
'B002-02783-00004'
'B002-03436-00017'
'B002-02525-00012'
'B002-02920-00016'
'B002-02920-00008'
'B002-01069-00003'
'B002-03436-00011'
'B002-00894-00087'
'B002-01755-00003'
'B002-00809-00002'
'B002-02931-00003'
'B002-00894-00088']

# 4분기
Year =[
'B002-02920-00005',
'B002-02723-00004',
'B002-00809-00002',
'B002-02920-00004',
'B002-00113-00001',
'B002-01603-00002',
'B002-00894-00088',
'B002-03436-00017',
'B002-02920-00025',
'B002-01069-00002',
'B002-00894-00087',
'B002-00894-00024',
'B002-00894-00089',
'B002-02063-00012',
'B002-03436-00011']

# %%
Year= ['B002-00113-00001',
'B002-02723-00004',
'B002-02920-00005',
'B002-01069-00002',
'B002-00809-00002',
'B002-02920-00016',
'B002-00894-00087',
'B002-02920-00008',
'B002-02783-00004',
'B002-00894-00088',
'B002-03436-00017',
'B002-02920-00009',
'B002-01069-00003',
'B002-00894-00024',
'B002-02063-00013']


year_idx = []
sns_idx = []

for i in range(len(Year)):
    year_idx.append(train[train["제품"] == Year[i]].index.item())
year = train.iloc[year_idx,6:].T

sns_na = train.iloc[year_idx,5].values

for i in range(len(sns_na)):
    sns_idx.append(key[key["브랜드"] == sns_na[i]].index.item())


print(year_idx)
print(sns_idx)
# Out:
# [485, 11595, 12336, 4470, 3481, 12347, 3899, 12339, 11767, 3900, 14586, 12340, 4471, 3837, 8708]
# [93, 2275, 2440, 896, 673, 2440, 748, 2440, 2322, 748, 2873, 2440, 896, 748, 1747]

# %%
sns = key.iloc[sns_idx,1:].drop_duplicates().T

from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2)

for i in year.columns:
    fig.add_trace(
        go.Scatter(x=list(year.index), y=list(year[i]),
                   name=i),
        row=1,col=1
    )

for i in sns.columns:
    fig.add_trace(
        go.Scatter(x=list(sns.index), y=list(sns[i]),
                   name=i, mode='markers'),
        row=1, col=2
    )

fig.update_layout(
    title_text="Year best Top15 and sns best Top15",
    height=650,
    width=1000,
    template='ggplot2'
)

fig.show()


print(year_idx)
print(sns_idx)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 매출량
sale = np.array(sales)
sale_sum = sale[:,6:].sum(axis = 0)

# 판매량
train_ = np.array(train)
train_sum = train_[:,6:465].sum(axis = 0)

# 매출량 판매량 데이터프레임
from datetime import datetime
sale_s = pd.DataFrame(sale_sum, columns = ['Sales'],index = pd.date_range('1/1/2022', periods = 459)).apply(pd.to_numeric)
train_s = pd.DataFrame(train_sum, columns = ['count'],index = pd.date_range('1/1/2022', periods = 459)).apply(pd.to_numeric)



from plotly.subplots import make_subplots
import plotly.graph_objects as go

# 판매량 및 매출량
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=("count","sales"), horizontal_spacing=0.08, vertical_spacing=0.08
)
fig.add_trace(go.Scatter(x=train_s.index, y=train_s['count'],name="count",showlegend=False, ), row=1, col=1)
fig.add_trace(go.Scatter(x=sale_s.index, y=sale_s['Sales'],name="sales",showlegend=False), row=1, col=2)

fig.update_layout(height =350, width =1000, title_text="Scatter Plot for train, sales", template='ggplot2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(sale_s.index), y= list(sale_s['Sales']),
              name='매출'))
fig.add_trace(
    go.Scatter(x = list(train_s.index), y= list(train_s['count']),
               name = '수량'))


# Set title
fig.update_layout(
    title_text="Overal Time series with Data"
)

# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=3,
                     label="3m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)
fig.update_layout(height =500, width =1000,template='ggplot2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 여기부터 모델링

# %%
import random
import os
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
from sklearn.preprocessing import LabelEncoder

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
CFG = {
    'TRAIN_WINDOW_SIZE':7, # 90일치로 학습
    'PREDICT_SIZE':21, # 21일치 예측
    'EPOCHS':10,
    'LEARNING_RATE':1e-4,
    'BATCH_SIZE':4096,
    'SEED':50
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED']) # Seed 고정

# %%
train_data = pd.read_csv('./train.csv').drop(columns=['ID', '제품'])

# %%
def scale_data(data):
  max_values = data.iloc[:, 4:].max(axis=1)
  min_values = data.iloc[:, 4:].min(axis=1)
  is_equal = max_values == min_values

  data.iloc[:, 4:] = np.where(is_equal[:, np.newaxis], 0, (data.iloc[:, 4:] - min_values[:, np.newaxis]) / (max_values - min_values)[:, np.newaxis])
  return max_values, min_values

scale_max_dict, scale_min_dict = scale_data(train_data)

# %%
#nn 임베딩
categorical_columns = ['대분류', '중분류', '소분류', '브랜드']
unique_counts = {col: train_data[col].nunique() for col in categorical_columns}


#각 범주형 열에 대한 임베딩 차원을 정의
# -> 각 범주형 변수('대분류', '중분류', '소분류', '브랜드')에 대해 사용할 임베딩 벡터의 차원(크기)을 설정
embedding_dimensions = {'대분류': 4, '중분류': 8, '소분류': 16, '브랜드': 50}


#각 범주형 열마다 임베딩 레이어를 생성
# -> 각 범주형 변수에 대한 임베딩 레이어를 PyTorch의 nn.Embedding을 사용
embedding_layers = {col: nn.Embedding(unique_counts[col] + 1, embedding_dimensions[col]) for col in categorical_columns}


#텍스트 라벨을 정수 인덱스에 매핑
# -> 각 범주형 변수의 고유한 문자열 라벨을 고유한 정수 값으로 변환. 이렇함으로써 머신러닝 모델이 이해할 수 있는 형태로 데이터를 변환 가능
integer_mapping = {col: {val: i+1 for i, val in enumerate(train_data[col].unique())} for col in categorical_columns}


#텍스트 라벨을 정수 인덱스로 교체
# -> 데이터프레임 내의 각 범주형 열의 문자열 라벨을 앞서 매핑한 정수 인덱스로 대체
for col in categorical_columns:
    train_data[col] = train_data[col].map(integer_mapping[col])


#PyTorch 텐서로 변환하고 임베딩 벡터 get
# -> 정수 인덱스로 변환된 데이터를 PyTorch 텐서로 변환한 후, 각 임베딩 레이어를 통과시켜 해당 범주형 변수의 임베딩 벡터를 얻음
for col in categorical_columns:
    tensor_data = torch.tensor(train_data[col].values)
    embedded_data = embedding_layers[col](tensor_data)

# %%
#customDataset
class CustomDataset(Dataset):
    def __init__(self, data, train_size=CFG['TRAIN_WINDOW_SIZE'], predict_size=CFG['PREDICT_SIZE'], is_inference=False):
        self.data = data.values # convert DataFrame to numpy array
        self.train_size = train_size
        self.predict_size = predict_size
        self.window_size = self.train_size + self.predict_size
        self.is_inference = is_inference

    def __len__(self):
        if self.is_inference:
            return len(self.data)
        else:
            return self.data.shape[0] * (self.data.shape[1] - self.window_size - 3)

    def __getitem__(self, idx):
        if self.is_inference:
            # 추론 시
            encode_info = self.data[idx, :4]
            window = self.data[idx, -self.train_size:]
            input_data = np.column_stack((np.tile(encode_info, (self.train_size, 1)), window))
            return input_data
        else:
            # 학습 시
            row = idx // (self.data.shape[1] - self.window_size - 3)
            col = idx % (self.data.shape[1] - self.window_size - 3)
            encode_info = self.data[row, :4]
            sales_data = self.data[row, 4:]
            window = sales_data[col : col + self.window_size]
            input_data = np.column_stack((np.tile(encode_info, (self.train_size, 1)), window[:self.train_size]))
            target_data = window[self.train_size:]
            return input_data, target_data

# %%
# CustomDataset 인스턴스 생성
dataset = CustomDataset(train_data)

# 전체 데이터셋의 크기
total_size = len(dataset)

# 분리할 데이터셋의 크기 계산
train_size = int(total_size * 0.8)
val_size = total_size - train_size

# random_split 함수를 사용해 데이터셋 분리
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# DataLoader 인스턴스 생성
train_loader = DataLoader(train_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False)

# %%
# Model Definition with Bi-directional LSTM
class BiLSTMModel(nn.Module):
    def __init__(self, input_size=5, hidden_size=1024, output_size=CFG['PREDICT_SIZE']):
        super(BiLSTMModel, self).__init__()
        self.hidden_size = hidden_size
        # Change: Added bidirectional=True
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, bidirectional=True)
        self.fc = nn.Sequential(
            # Change: 2 * hidden_size
            nn.Linear(2 * hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(hidden_size, output_size)
        )
        self.actv = nn.ReLU()

    def forward(self, x):
        batch_size = x.size(0)
        hidden = self.init_hidden(batch_size, x.device)
        lstm_out, hidden = self.lstm(x, hidden)
        # Change: last output from both directions
        last_output = torch.cat((lstm_out[:, -1, :self.hidden_size], lstm_out[:, 0, self.hidden_size:]), dim=1)
        output = self.actv(self.fc(last_output))
        return output.squeeze(1)

    def init_hidden(self, batch_size, device):
        # Change: 2 hidden states
        return (torch.zeros(2, batch_size, self.hidden_size, device=device),
                torch.zeros(2, batch_size, self.hidden_size, device=device))

# %%
def train(model, optimizer, train_loader, val_loader, device):
    model.to(device)
    criterion = nn.MSELoss().to(device)
    best_loss = 9999999
    best_model = None

    for epoch in range(1, CFG['EPOCHS']+1):
        model.train()
        train_loss = []
        train_mae = []
        for X, Y in tqdm(iter(train_loader)):
            X = X.float().to(device)
            Y = Y.float().to(device)

            optimizer.zero_grad()

            output = model(X)
            loss = criterion(output, Y)

            loss.backward()
            optimizer.step()

            train_loss.append(loss.item())

        val_loss = validation(model, val_loader, criterion, device)
        print(f'Epoch : [{epoch}] Train Loss : [{np.mean(train_loss):.5f}] Val Loss : [{val_loss:.5f}]')

        if best_loss > val_loss:
            best_loss = val_loss
            best_model = model
            print('Model Saved')
    return best_model

# %%
def validation(model, val_loader, criterion, device):
    model.eval()
    val_loss = []

    with torch.no_grad():
        for X, Y in tqdm(iter(val_loader)):
            X = X.float().to(device)
            Y = Y.float().to(device)

            output = model(X)
            loss = criterion(output, Y)

            val_loss.append(loss.item())
    return np.mean(val_loss)

# %%
model = BiLSTMModel()
optimizer = torch.optim.Adam(params = model.parameters(), lr = CFG["LEARNING_RATE"])
infer_model = train(model, optimizer, train_loader, val_loader, device)

# %%
def make_predict_data(data, train_size=CFG['TRAIN_WINDOW_SIZE']):
    '''
    평가 데이터(Test Dataset)를 추론하기 위한 Input 데이터를 생성
    data : 일별 판매량
    train_size : 추론을 위해 필요한 일별 판매량 기간 (= 학습에 활용할 기간)
    '''
    num_rows = len(data)

    input_data = np.empty((num_rows, train_size, len(data.iloc[0, :4]) + 1))

    for i in tqdm(range(num_rows)):
        encode_info = np.array(data.iloc[i, :4])
        sales_data = np.array(data.iloc[i, -train_size:])

        window = sales_data[-train_size : ]
        temp_data = np.column_stack((np.tile(encode_info, (train_size, 1)), window[:train_size]))
        input_data[i] = temp_data

    return input_data

# %%
test_input = make_predict_data(train_data)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y

    def __getitem__(self, index):
        if self.Y is not None:
            return torch.Tensor(self.X[index]), torch.Tensor(self.Y[index])
        return torch.Tensor(self.X[index])

    def __len__(self):
        return len(self.X)

# %%
test_dataset = CustomDataset(test_input, None)
test_loader = DataLoader(test_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %%
def inference(model, test_loader, device):
    predictions = []

    with torch.no_grad():
        for X in tqdm(iter(test_loader)):
            X = X.to(device)

            output = model(X)

            # 모델 출력인 output을 CPU로 이동하고 numpy 배열로 변환
            output = output.cpu().numpy()

            predictions.extend(output)

    return np.array(predictions)

# %%
test_dataset

# %%
pred = inference(infer_model, test_loader, device)

# %%
for idx in range(len(pred)):
    pred[idx, :] = pred[idx, :] * (scale_max_dict[idx] - scale_min_dict[idx]) + scale_min_dict[idx]

# 결과 후처리
pred = np.round(pred, 0).astype(int)

# %%
pred.shape

# %%
submit = pd.read_csv('./sample_submission.csv')

# %%
submit.iloc[:,1:] = pred
submit.head()

# %%
submit.to_csv('./Love.csv', index=False)
